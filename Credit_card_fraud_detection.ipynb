# %%
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score,f1_score
from sklearn.preprocessing import LabelEncoder,StandardScaler
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from imblearn.over_sampling import SMOTE
import joblib
from joblib import dump, load
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.metrics import roc_curve, auc

# %% [markdown]
# # **1-Read a data**

# %%
train_data = pd.read_csv('fraudTrain.csv')
train_data.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   Unnamed: 0             1296675 non-null  int64
#  1   trans_date_trans_time  1296675 non-null  object
#  2   cc_num                 1296675 non-null  int64
#  3   merchant               1296675 non-null  object
#  4   category               1296675 non-null  object
#  5   amt                    1296675 non-null  float64
#  6   first                  1296675 non-null  object
#  7   last                   1296675 non-null  object
#  8   gender                 1296675 non-null  object
#  9   street                 1296675 non-null  object
#  10  city                   1296675 non-null  object
#  11  state                  1296675 non-null  object
#  12  zip                    1296675 non-null  int64
#  13  lat                    1296675 non-null  float64
# ...

# %%
train_data.describe()
# Out:
#          Unnamed: 0        cc_num           amt           zip           lat  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean   6.483370e+05  4.171920e+17  7.035104e+01  4.880067e+04  3.853762e+01
# std    3.743180e+05  1.308806e+18  1.603160e+02  2.689322e+04  5.075808e+00
# min    0.000000e+00  6.041621e+10  1.000000e+00  1.257000e+03  2.002710e+01
# 25%    3.241685e+05  1.800429e+14  9.650000e+00  2.623700e+04  3.462050e+01
# 50%    6.483370e+05  3.521417e+15  4.752000e+01  4.817400e+04  3.935430e+01
# 75%    9.725055e+05  4.642255e+15  8.314000e+01  7.204200e+04  4.194040e+01
# max    1.296674e+06  4.992346e+18  2.894890e+04  9.978300e+04  6.669330e+01
#
#                long      city_pop     unix_time     merch_lat    merch_long  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean  -9.022634e+01  8.882444e+04  1.349244e+09  3.853734e+01 -9.022646e+01
# ...

# %%
train_data.dtypes
# Out:
# Unnamed: 0                 int64
# trans_date_trans_time     object
# cc_num                     int64
# merchant                  object
# category                  object
# amt                      float64
# first                     object
# last                      object
# gender                    object
# street                    object
# city                      object
# state                     object
# zip                        int64
# lat                      float64
# long                     float64
# city_pop                   int64
# job                       object
# dob                       object
# trans_num                 object
# unix_time                  int64
# merch_lat                float64
# merch_long               float64
# is_fraud                   int64
# dtype: object

# %%
train_data.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %% [markdown]
# # **2-Preprocessing**

# %%
train_data["trans_date_trans_time"] = pd.to_datetime(train_data["trans_date_trans_time"])
train_data["dob"] = pd.to_datetime(train_data["dob"])
train_data['trans_hour'] = train_data['trans_date_trans_time'].dt.hour
train_data['trans_day'] = train_data['trans_date_trans_time'].dt.dayofweek
train_data['trans_month'] = train_data['trans_date_trans_time'].dt.month
train_data['dist_lat'] = train_data['lat'] - train_data['merch_lat']
train_data['dist_long'] = train_data['long'] - train_data['merch_long']
train_data['dist_total'] = np.sqrt(train_data['dist_lat']**2 + train_data['dist_long']**2)
train_data
# Out:
#          Unnamed: 0 trans_date_trans_time               cc_num  \
# 0                 0   2019-01-01 00:00:18     2703186189652095
# 1                 1   2019-01-01 00:00:44         630423337322
# 2                 2   2019-01-01 00:00:51       38859492057661
# 3                 3   2019-01-01 00:01:16     3534093764340240
# 4                 4   2019-01-01 00:03:06      375534208663984
# ...             ...                   ...                  ...
# 1296670     1296670   2020-06-21 12:12:08       30263540414123
# 1296671     1296671   2020-06-21 12:12:19     6011149206456997
# 1296672     1296672   2020-06-21 12:12:32     3514865930894695
# 1296673     1296673   2020-06-21 12:13:36     2720012583106919
# 1296674     1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt  \
# 0                 fraud_Rippin, Kub and Mann       misc_net    4.97
# 1            fraud_Heller, Gutmann and Zieme    grocery_pos  107.23
# ...

# %%
train_data.drop(columns=['Unnamed: 0','cc_num','first', 'last', 'street', 'city', 'state', 'zip', 'dob', 'trans_num','trans_date_trans_time'],inplace=True)
train_data
# Out:
#                                     merchant       category     amt gender  \
# 0                 fraud_Rippin, Kub and Mann       misc_net    4.97      F
# 1            fraud_Heller, Gutmann and Zieme    grocery_pos  107.23      F
# 2                       fraud_Lind-Buckridge  entertainment  220.11      M
# 3         fraud_Kutch, Hermiston and Farrell  gas_transport   45.00      M
# 4                        fraud_Keeling-Crist       misc_pos   41.96      M
# ...                                      ...            ...     ...    ...
# 1296670                    fraud_Reichel Inc  entertainment   15.56      M
# 1296671             fraud_Abernathy and Sons    food_dining   51.70      M
# 1296672                 fraud_Stiedemann Ltd    food_dining  105.93      M
# 1296673  fraud_Reinger, Weissnat and Strosin    food_dining   74.90      M
# 1296674  fraud_Langosh, Wintheiser and Hyatt    food_dining    4.30      M
#
# ...

# %%
numerical_cols = train_data.select_dtypes(include=np.number).columns
for i in numerical_cols:
    plt.boxplot(train_data[i])
    plt.title(i)
    plt.show()

# %%
num_colum = train_data.select_dtypes(include=np.number).columns.drop('is_fraud', errors='ignore')

# %%
for col in num_colum:
    Q1 = train_data[col].quantile(0.25)
    Q3 = train_data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    train_data[col] = train_data[col].clip(lower=lower, upper=upper)

# %%
train_data['is_fraud'].value_counts()
# Out:
# is_fraud
# 0    1289169
# 1       7506
# Name: count, dtype: int64

# %%
numerical_cols = train_data.select_dtypes(include=np.number).columns
for i in numerical_cols:
    plt.boxplot(train_data[i])
    plt.title(i)
    plt.show()

# %%
train_data.isna().sum()
# Out:
# merchant       0
# category       0
# amt            0
# gender         0
# lat            0
# long           0
# city_pop       0
# job            0
# unix_time      0
# merch_lat      0
# merch_long     0
# is_fraud       0
# trans_hour     0
# trans_day      0
# trans_month    0
# dist_lat       0
# dist_long      0
# dist_total     0
# dtype: int64

# %%
train_data.dropna(inplace=True)

# %%
train_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
le_merchant= LabelEncoder()
train_data["merchant"] = le_merchant.fit_transform(train_data["merchant"])
le_category= LabelEncoder()
train_data["category"] = le_category.fit_transform(train_data["category"])
le_gender= LabelEncoder()
train_data["gender"] =le_gender.fit_transform(train_data["gender"])
le_job= LabelEncoder()
train_data["job"] = le_job.fit_transform(train_data["job"])

# %%
for i in train_data:
  plt.hist(train_data[i])
  plt.title(i)
  plt.show()

# %%
train_data
# Out:
#          merchant  category      amt  gender      lat      long  city_pop  \
# 0             514         8    4.970       0  36.0788  -81.1781    3495.0
# 1             241         4  107.230       0  48.8878 -118.2105     149.0
# 2             390         0  193.375       1  42.1808 -112.2620    4154.0
# 3             360         2   45.000       1  46.2306 -112.1138    1939.0
# 4             297         9   41.960       1  38.4207  -79.4629      99.0
# ...           ...       ...      ...     ...      ...       ...       ...
# 1296670       499         0   15.560       1  37.7175 -112.4777     258.0
# 1296671         2         1   51.700       1  39.2667  -77.5101     100.0
# 1296672       599         1  105.930       1  32.9396 -105.8189     899.0
# 1296673       509         1   74.900       1  43.3526 -102.5411    1126.0
# 1296674       370         1    4.300       1  45.8433 -113.8748     218.0
#
#          job   unix_time  merch_lat  merch_long  is_fraud  trans_hour  \
# ...

# %%
exit_counts = train_data["is_fraud"].value_counts()
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.pie(exit_counts, labels=["No", "YES"], autopct="%0.0f%%")
plt.title("is_fraud Counts")
plt.tight_layout()
plt.show()

# %%
exit_counts = train_data["is_fraud"].value_counts()
exit_percent = exit_counts / exit_counts.sum() * 100
plt.figure(figsize=(8,5))
sns.barplot(x=exit_percent.index, y=exit_percent.values, palette="coolwarm")
plt.xticks([0,1], ["No", "Yes"])
plt.ylabel("Percentage (%)")
plt.title("is_fraud")
for i, v in enumerate(exit_percent.values):
    plt.text(i, v + 0.5, f"{v:.2f}%", ha='center')
plt.show()
# Out:
# C:\Users\Elabsy\AppData\Local\Temp\ipykernel_12648\3013258874.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=exit_percent.index, y=exit_percent.values, palette="coolwarm")

# %% [markdown]
# # **3-Train the Model**

# %%
X = train_data.drop(columns=["is_fraud"], inplace = False)
Y = train_data["is_fraud"]

# %%
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X, Y)

# %%
scaler = StandardScaler()
X_res = scaler.fit_transform(X_res)
y_res = np.array(y_res)

# %% [markdown]
# # **XGBOOST**

# %%
count_no = sum(y_res == 0)
count_yes = sum(y_res == 1)
scale_pos_weight = count_no / count_yes
print("Scale_pos_weight:", scale_pos_weight)
# Out:
# Scale_pos_weight: 1.0

# %%
model = xgb.XGBClassifier(
    n_estimators=1000,
    learning_rate=0.05,
    max_depth=5,
    subsample=0.8,
    colsample_bytree=0.8,
    eval_metric='logloss',
    scale_pos_weight=scale_pos_weight,
    use_label_encoder=False,
    random_state=42
)

# %%
model.fit(X_res, y_res)
# Out:
# C:\Users\Elabsy\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\xgboost\training.py:200: UserWarning: [17:41:54] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
# ...

# %%
model.score(X_res, y_res)
# Out:
# 0.9645748540338777

# %% [markdown]
# # **Logistic Regression**

# %%
model1=LogisticRegression()
model1.fit(X_res,y_res)
# Out:
# LogisticRegression()

# %%
model1.score(X_res, y_res)
# Out:
# 0.8131393168777716

# %% [markdown]
# # **Decision Tree**

# %%
model2=DecisionTreeClassifier()
model2.fit(X_res,y_res)
# Out:
# DecisionTreeClassifier()

# %%
model2.score(X_res, y_res)
# Out:
# 1.0

# %%
importances =model.feature_importances_

# %%
features = X.columns
importances = model.feature_importances_
indices = np.argsort(importances)

plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %% [markdown]
# # **4-Test the model**

# %%
test_data = pd.read_csv('fraudTest.csv')
test_data
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2020-06-21 12:14:25  2291163933867244
# 1                1   2020-06-21 12:14:33  3573030041201292
# 2                2   2020-06-21 12:14:53  3598215285024754
# 3                3   2020-06-21 12:15:15  3591919803438423
# 4                4   2020-06-21 12:15:17  3526826139003047
# ...            ...                   ...               ...
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...

# %%
test_data["trans_date_trans_time"] = pd.to_datetime(test_data["trans_date_trans_time"])
test_data["dob"] = pd.to_datetime(test_data["dob"])
test_data['trans_hour'] = test_data['trans_date_trans_time'].dt.hour
test_data['trans_day'] = test_data['trans_date_trans_time'].dt.dayofweek
test_data['trans_month'] = test_data['trans_date_trans_time'].dt.month
test_data['dist_lat'] = test_data['lat'] - test_data['merch_lat']
test_data['dist_long'] = test_data['long'] - test_data['merch_long']
test_data['dist_total'] = np.sqrt(test_data['dist_lat']**2 + test_data['dist_long']**2)
test_data.drop(columns=['Unnamed: 0','cc_num','first', 'last', 'street', 'city', 'state', 'zip', 'dob', 'trans_num','trans_date_trans_time'],inplace=True)
test_data
# Out:
#                                     merchant        category     amt gender  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86      M
# 1                       fraud_Sporer-Keebler   personal_care   29.84      F
# 2       fraud_Swaniawski, Nitzsche and Welch  health_fitness   41.28      F
# 3                          fraud_Haley Group        misc_pos   60.05      M
# 4                      fraud_Johnston-Casper          travel    3.19      M
# ...                                      ...             ...     ...    ...
# 555714                 fraud_Reilly and Sons  health_fitness   43.77      M
# 555715                  fraud_Hoppe-Parisian       kids_pets  111.84      M
# 555716                       fraud_Rau-Robel       kids_pets   86.88      F
# 555717                 fraud_Breitenberg LLC          travel    7.99      M
# 555718                     fraud_Dare-Marvin   entertainment   38.13      M
#
# ...

# %%
test_data.isna().sum()
# Out:
# merchant       0
# category       0
# amt            0
# gender         0
# lat            0
# long           0
# city_pop       0
# job            0
# unix_time      0
# merch_lat      0
# merch_long     0
# is_fraud       0
# trans_hour     0
# trans_day      0
# trans_month    0
# dist_lat       0
# dist_long      0
# dist_total     0
# dtype: int64

# %%
test_data.dropna(inplace=True)

# %%
def safe_encode(le, series):
    le_dict = dict(zip(le.classes_, le.transform(le.classes_)))
    return series.apply(lambda x: le_dict.get(x, -1))

test_data["merchant"] = safe_encode(le_merchant, test_data["merchant"])
test_data["category"] = safe_encode(le_category, test_data["category"])
test_data["gender"]   = safe_encode(le_gender, test_data["gender"])
test_data["job"]      = safe_encode(le_job, test_data["job"])

# %%
X_test = test_data.drop(columns=["is_fraud"], inplace = False)
X_test = X_test[X.columns]
Y_test = test_data["is_fraud"]

# %%
X_test = scaler.transform(X_test)

# %% [markdown]
# # **XGBOOST**

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(555719,))

# %%
y_prob = model.predict_proba(X_test)[:,1]
threshold = 0.3
y_pred = (y_prob > threshold).astype(int)

# %%
thresholds = np.arange(0.1, 0.6, 0.05)
min_len = min(len(Y_test), len(y_prob))
Y_test_1 = Y_test.iloc[:min_len]
y_prob_1 = y_prob[:min_len]

for t in thresholds:
    y_pred_t = (y_prob_1 > t).astype(int)
    f1_t = f1_score(Y_test_1, y_pred_t)
    print(f"Threshold {t:.2f} -> F1-score: {f1_t:.4f}")
# Out:
# Threshold 0.10 -> F1-score: 0.0369
# Threshold 0.15 -> F1-score: 0.0500
# Threshold 0.20 -> F1-score: 0.0634
# Threshold 0.25 -> F1-score: 0.0766
# Threshold 0.30 -> F1-score: 0.0901
# Threshold 0.35 -> F1-score: 0.1032
# Threshold 0.40 -> F1-score: 0.1163
# Threshold 0.45 -> F1-score: 0.1313
# Threshold 0.50 -> F1-score: 0.1457
# Threshold 0.55 -> F1-score: 0.1621

# %%
model.score(X_test, Y_test)
# Out:
# 0.9679712228662327

# %%
accuracy_score(Y_test, y_pred)
# Out:
# 0.9357247097903797

# %%
cm = confusion_matrix(Y_test, y_pred)
print(cm)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title("Confusion Matrix")
plt.show()
# Out:
# [[518231  35343]
#  [   376   1769]]

# %%
fpr, tpr, thresholds = roc_curve(Y_test, y_prob)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97    553574
#            1       0.05      0.82      0.09      2145
#
#     accuracy                           0.94    555719
#    macro avg       0.52      0.88      0.53    555719
# weighted avg       1.00      0.94      0.96    555719

# %% [markdown]
# # **Logistic Regression**

# %%
y_pred1 = model1.predict(X_test)
y_pred1
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(555719,))

# %%
model1.score(X_test, Y_test)
# Out:
# 0.8803945879122362

# %% [markdown]
# # **Decision Tree**

# %%
y_pred2 = model2.predict(X_test)
y_pred2
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(555719,))

# %%
model2.score(X_test, Y_test)
# Out:
# 0.9097673464466753

# %% [markdown]
# # **JOBLIB**

# %%
dump(model, 'model.pkl')
dump(scaler, 'scaler.pkl')
dump({'merchant': le_merchant, 'category': le_category, 'gender': le_gender, 'job': le_job}, 'encoders.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dump(model, 'model.pkl')
#       2 dump(scaler, 'scaler.pkl')
#       3 dump({'merchant': le_merchant, 'category': le_category, 'gender': le_gender, 'job': le_job}, 'encoders.pkl')
#
# NameError: name 'dump' is not defined
